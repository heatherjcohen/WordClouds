# %%
#P&P
from os import path
import numpy as np
import matplotlib.pyplot as plt
import os
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont
from PIL import ImageEnhance
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import requests
import urllib.request
import time
from bs4 import BeautifulSoup
import re
import numpy as np
from io import BytesIO
import datetime

# %%
stopwords = set(STOPWORDS)
#stopwords.add('dah')

# %%
def getcorpus(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    words = soup.get_text()
    words= re.sub("[^a-zA-Z' ]+", " ", words)
    return words

def cloud(text,imgurl,save):
    response1 = requests.get(imgurl)
    img = Image.open(BytesIO(response1.content))
    mask = np.array(img)
    wordcloud = WordCloud(stopwords = stopwords, background_color="white", max_words=7000, mask=mask).generate(text)
    image_colors = ImageColorGenerator(mask)
    plt.figure(figsize=[8,8])
    plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation="bilinear")
    plt.axis("off")
    if save == "yes":
        plt.savefig("viz"+str(datetime.datetime.now().second)+str(datetime.datetime.now().minute)+".png", format="png")
    plt.show()
    plt.imshow(mask, cmap=plt.cm.gray, interpolation='bilinear')
    plt.axis("off")
    plt.show()
    
def cloudtweek(text,imgurl,maxsize , maxwords, save):
    response1 = requests.get(imgurl)
    img = Image.open(BytesIO(response1.content))
    mask = np.array(img)
    wordcloud = WordCloud(stopwords = stopwords, background_color="white", max_words=maxwords,max_font_size=maxsize,  mask=mask).generate(text)
    image_colors = ImageColorGenerator(mask)
    plt.figure(figsize=[8,8])
    plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation="bilinear")
    plt.axis("off")
    if save == "yes":
        plt.savefig("viz"+str(datetime.datetime.now().second)+str(datetime.datetime.now().minute)+".png", format="png")
    plt.show()
    plt.imshow(mask, cmap=plt.cm.gray, interpolation='bilinear')
    plt.axis("off")
    plt.show()

# %%
words = getcorpus('http://www.gutenberg.org/files/1342/1342.txt')

# %%
cloud(words,'https://d1e4pidl3fu268.cloudfront.net/0a088f50-fb54-4d86-b048-03d2f3568c30/JaneMrBingley.crop_627x470_0%2C6.preview.jpg', 'no')

# %%
cloudtweek(words,'https://d1e4pidl3fu268.cloudfront.net/0a088f50-fb54-4d86-b048-03d2f3568c30/JaneMrBingley.crop_627x470_0%2C6.preview.jpg', 30, 4000, 'no')

# %%
cloud(words, 'https://i.etsystatic.com/7258916/r/il/b664ed/1704486884/il_fullxfull.1704486884_s3r1.jpg', 'yes')

# %%
cloud(words, 'https://i.pinimg.com/originals/32/25/ce/3225ce4dd5074e1eb52055e19cc69e64.jpg', "no")

# %%
#Sense and Sensibility 
words = getcorpus('http://www.gutenberg.org/cache/epub/161/pg161.txt')

# %%
cloud(words, 'https://cdn.vox-cdn.com/thumbor/81Ky1g0CBkE6It-efKGzW5UMaCo=/0x0:4063x2700/1200x800/filters:focal(2755x669:3405x1319)/cdn.vox-cdn.com/uploads/chorus_image/image/55715237/senseandsensibility.0.jpg', "no")

# %%
cloud(words,"https://i.pinimg.com/originals/d4/fc/9c/d4fc9c846938291baec8259da3a62096.jpg", "yes")

# %%
cloudtweek(words,"https://i.pinimg.com/originals/d4/fc/9c/d4fc9c846938291baec8259da3a62096.jpg", 80, 4000, "no")

# %%
cloud(words, "https://periodpiano.com/wp-content/uploads/2016/04/Erard_Grand_Piano_1832.jpg", "no")

# %%
####Emma

words = getcorpus('https://www.gutenberg.org/files/158/158-0.txt')

# %%
cloud(words, 'https://fanart.tv/fanart/movies/3573/movieposter/emma-55e095334af49.jpg', "no")
