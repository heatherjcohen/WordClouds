# %%
import feedparser

# %%
d = feedparser.parse('http://feeds.feedburner.com/RadioDramaRevival')

# %%
print(d['feed']['title'])
# Out:
# Radio Drama Revival

# %%
print(d.feed.subtitle)
# Out:
# Radio Drama Revival is dedicated to showcasing the diversity and vitality of modern audio fiction. Now in our 12th year!

# %%
print(len(d['entries']))
# Out:
# 167

# %%
d.entries[0].description
# Out:
# 'This week, we\'ve got a form-breaking, innovative space horror from the mind of the amazing Jordan Cobb: Janus Descending. Join us in listening to this tragic nightmare situation wrapped up in even more beauty than looking out at the night sky.\n\nLike what you hear? Us too. You can support Jordan Cobb\'s work on Patreon: <a href="https://www.patreon.com/nosuchthingproductions">https://www.patreon.com/nosuchthingproductions</a>\n\natreon.com/radiodramarevival RDR’s patreon\nPatreon.com/WilWilliams Wil’s Patreon\nPatreon.com/elenafernandezcollins Ely’s Patreon\nPatreon.com/albasalix Eli and Sean’s Patreon\nFinalrune.com Fred’s website<img src="http://feeds.feedburner.com/~r/RadioDramaRevival/~4/mdJxu_yJgM4" height="1" width="1" alt=""/>'

# %%
for post in d.entries:
    print(post.description)
# Out:
# This week, we've got a form-breaking, innovative space horror from the mind of the amazing Jordan Cobb: Janus Descending. Join us in listening to this tragic nightmare situation wrapped up in even more beauty than looking out at the night sky.
#
# Like what you hear? Us too. You can support Jordan Cobb's work on Patreon: <a href="https://www.patreon.com/nosuchthingproductions">https://www.patreon.com/nosuchthingproductions</a>
#
# atreon.com/radiodramarevival RDR’s patreon
# Patreon.com/WilWilliams Wil’s Patreon
# Patreon.com/elenafernandezcollins Ely’s Patreon
# Patreon.com/albasalix Eli and Sean’s Patreon
# Finalrune.com Fred’s website<img src="http://feeds.feedburner.com/~r/RadioDramaRevival/~4/mdJxu_yJgM4" height="1" width="1" alt=""/>
# What makes a place a place? What makes something scary? This week, join both David Rheinstrom and Elena Fernández Collins as they interview Eleanor Hyde, one of the creators of the Midwest Gothic podcast, Unwell.
#
# ...

# %%
import re

lines = []
for post in d.entries:
    post.description.split('Like what')
    s=post.description.split('Like what')[0].split('You can')
    lines.append(s[0].split('<a href')[0])

# %%
corpus = " ".join(lines)

# %%
corpus=re.sub("[^a-zA-Z' ]+", '', corpus)

# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
% matplotlib inline

# %%
wordcloud = WordCloud().generate(result)

# %%
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
def word_count(str):
    counts = dict()
    words = str.split()

    for word in words:
        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1

    return counts

value_counts= word_count(result)

for key, value in sorted(value_counts.items(), reverse=True, key=lambda item: item[1]):
    print("%s: %s" % (key, value))

# %%
for key, value in sorted(value_counts.items(), reverse=True, key=lambda item: item[1]):
    print("%s: %s" % (key, value))
# Out:
# Radio: 82
# Drama: 82
# about: 81
# Episode: 66
# first: 62
# I: 57
# audio: 54
# episode: 54
# show: 54
# David: 51
# Revival: 38
# new: 37
# talk: 34
# It's: 31
# Revivalimg: 31
# post: 31
# fiction: 30
# play: 30
# appeared: 30
# what: 29
# story: 28
# podcast: 27
# hear: 27
# it's: 25
# has: 23
# some: 21
# over: 21
# drama: 21
# world: 20
# own: 19
# how: 19
# we're: 19
# name: 19
# time: 18
# piece: 18
# Audio: 18
# will: 18
# joins: 18
# production: 18
# horror: 17
# interview: 17
# like: 17
# feature: 17
# episodes: 17
# series: 17
# your: 16
# old: 16
# take: 16
# love: 16
# which: 16
# back: 15
# when: 15
# can: 15
# or: 15
# th: 15
# Hour: 15
# where: 15
# space: 14
# just: 14
# creator: 14
# get: 14
# only: 14
# if: 14
# do: 14
# good: 14
# well: 14
# chat: 14
# radio: 14
# producer: 14
# week's: 13
# also: 13
# way: 13
# work: 13
# discuss: 13
# its: 13
# little: 13
# Matthew: 13
# you'll: 13
# got: 12
# those: 12
# interviews: 12
# great: 12
# life: 12
# playing: 12
# ...

# %%
stopwords = ['the', 'of', 'and', 'a', 'to', 'in','is', 'with', 'height', 'width', 'alt', 
             'for', 'The', 'his', 'by', 'on', 'this', 'as', 'Radio', 'Drama', 'week',
             'This', 'that', 'from', 'an', 'we', 'Episode', 'you', 
             'I', 'it', 'he', 'be', 'who', 'out', 'at', 'into', 'two', 'all', 'up', 'their', 'me',
            'have', 'our', 'us', 'are', "more", "It's", 'she', 'her', 'was', 'so', 'not', "We", 'one',
            'but', 'they', 'as', 'him', 'new', 'talk', 'show', 'podcast', 'radio', 'drama', 'episode',
            'production']
querywords = corpus.split()

resultwords  = [word for word in querywords if word.lower() not in stopwords]
result = ' '.join(resultwords)

print(result)
# Out:
# we've got formbreaking innovative space horror mind amazing Jordan Cobb Janus Descending Join listening tragic nightmare situation wrapped even beauty than looking night sky What makes place place What makes something scary join both David Rheinstrom Elena Fernndez Collins interview Eleanor Hyde creators Midwest Gothic Unwell Sink your teeth Midwestern Gothic audio fiction wonderful Harlife NFP It's got creepies It's got spookies doesn't too many scary scaries even those worried about horror like own sweet David Rheinstrom should just fine join week's feature Unwell subscribe website join David interviews effervescent Shenee Howard creator Fan Wars Empire Claps Back about owns art what makes romantic pairing interesting black joy media get showcase fandomtastic romcom Fan Wars Empire Claps Back Join great how fandom brings together tears apart makes question owns art also makes big swoon join host David Rheinstrom conversation doula Keisha TK Dutes about Bondfire's Weeksvile Project 
# ...

# %%
wordcloud = WordCloud(max_font_size=50, max_words=1000, background_color="white").generate(result)
plt.figure(figsize=[30,30])
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
wordcloud.to_file("RDRcloud2.png")

# %%
mask = np.array(Image.open("result.png"))
mask
# Out:
# array([[[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
# ...

# %%
def transform_format(val):
    if val == 0:
        return 255
    else:
        return val

# %%
import os
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()
alice_coloring = np.array(Image.open(path.join(d, "result.png")))

# %%
mask = np.array(Image.open("RDR-Logo-Final.png"))
wordcloud_usa = WordCloud(background_color="white", mode="RGBA", max_words=1000, mask=mask).generate(result)

# create coloring from image
image_colors = ImageColorGenerator(mask)
plt.figure(figsize=[7,7])
plt.imshow(wordcloud_usa.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis("off")

# store to file
plt.savefig("RDR4.png", format="png")

plt.show()

# %%
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont
from PIL import ImageEnhance

width = 854
height = 480
black = (0,0,0)
text = "RDR"
white = (255,255,255)
font = ImageFont.truetype("Arial.ttf",400)
img = Image.new("RGBA", (width,height),white)
draw = ImageDraw.Draw(img)
w, h = draw.textsize(text, font)
draw.text(((width-w)/2,(height-h)/2),text,black,font=font)
draw = ImageDraw.Draw(img)
#img.putalpha
img.save("result.png")
img
# Out:
# <PIL.Image.Image image mode=RGBA size=854x480 at 0x117AC6630>

# %%
from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

from wordcloud import WordCloud, STOPWORDS

# get data directory (using getcwd() is needed to support running example in generated IPython notebook)
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()

# Read the whole text.
text = result

# read the mask image
# taken from
# http://www.stencilry.org/stencils/movies/alice%20in%20wonderland/255fk.jpg
alice_mask = np.array(Image.open(path.join(d, "result.png")))



wc = WordCloud(background_color="white", max_words=2000, mask=alice_mask,
                contour_width=3, contour_color='steelblue')

# generate word cloud
wc.generate(text)

# store to file
wc.to_file(path.join(d, "RDR6.png"))

# show
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.figure()
plt.imshow(alice_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# get data directory (using getcwd() is needed to support running example in generated IPython notebook)
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()

# Read the whole text.
text = result

# read the mask / color image taken from
# http://jirkavinse.deviantart.com/art/quot-Real-Life-quot-Alice-282261010
alice_coloring = np.array(Image.open(path.join(d, "RDR-T-Shirt-04.png")))


wc = WordCloud(background_color="white", max_words=2000, mask=alice_coloring,
                max_font_size=40, random_state=42)
# generate word cloud
wc.generate(text)

# create coloring from image
image_colors = ImageColorGenerator(alice_coloring)

# show
fig, axes = plt.subplots(1, 3)
axes[0].imshow(wc, interpolation="bilinear")
# recolor wordcloud and show
# we could also give color_func=image_colors directly in the constructor
axes[1].imshow(wc.recolor(color_func=image_colors), interpolation="bilinear")
axes[2].imshow(alice_coloring, cmap=plt.cm.gray, interpolation="bilinear")
for ax in axes:
    ax.set_axis_off()
plt.show()

# %%
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont
from PIL import ImageEnhance

width = 854
height = 480
black = (0,0,0)
text = "*"
white = (255,255,255)
font = ImageFont.truetype("Arial.ttf",800)
img = Image.new("RGBA", (width,height),white)
draw = ImageDraw.Draw(img)
w, h = draw.textsize(text, font)
draw.text(((width-w)/2,(height-h)/2),text,black,font=font)
draw = ImageDraw.Draw(img)
#img.putalpha
img.save("and.png")
img
# Out:
# <PIL.Image.Image image mode=RGBA size=854x480 at 0x117EF5B00>

# %%
from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

from wordcloud import WordCloud, STOPWORDS

# get data directory (using getcwd() is needed to support running example in generated IPython notebook)
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()

# Read the whole text.
text = result

# read the mask image
# taken from
# http://www.stencilry.org/stencils/movies/alice%20in%20wonderland/255fk.jpg
alice_mask = np.array(Image.open(path.join(d, "and.png")))



wc = WordCloud(background_color="white", max_words=2000, mask=alice_mask,
                contour_width=3, contour_color='steelblue')

# generate word cloud
wc.generate(text)

# store to file
wc.to_file(path.join(d, "RDR7.png"))

# show
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.figure()
plt.imshow(alice_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis("off")
plt.show()
